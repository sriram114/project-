# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
body=pd.read_csv('C:/body/bodyfat (1).csv')

# %%
body
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
body.shape
# Out:
# (252, 15)

# %%
body.tail()
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9

# %%
body.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
boss=body.drop(['Density','BodyFat','Height','Neck','Chest','Abdomen','Hip','Thigh','Knee','Ankle','Biceps','Forearm','Wrist'],axis=1)

# %%
boss
# Out:
#      Age  Weight
# 0     23  154.25
# 1     22  173.25
# 2     22  154.00
# 3     26  184.75
# 4     24  184.25
# ..   ...     ...
# 247   70  134.25
# 248   72  201.00
# 249   72  186.75
# 250   72  190.75
# 251   74  207.50
#
# [252 rows x 2 columns]

# %%
x=boss.iloc[:,0].values.reshape(-1,1)
y=boss.iloc[:,-1].values.reshape(-1,1)

# %%
x
# Out:
# array([[23],
#        [22],
#        [22],
#        [26],
#        [24],
#        [24],
#        [26],
#        [25],
#        [25],
#        [23],
#        [26],
#        [27],
#        [32],
#        [30],
#        [35],
#        [35],
#        [34],
#        [32],
#        [28],
#        [33],
#        [28],
#        [28],
#        [31],
#        [32],
#        [28],
#        [27],
#        [34],
#        [31],
#        [27],
#        [29],
#        [32],
#        [29],
#        [27],
#        [41],
#        [41],
#        [49],
#        [40],
#        [50],
#        [46],
#        [50],
#        [45],
#        [44],
#        [48],
#        [41],
#        [39],
#        [43],
#        [40],
#        [39],
#        [45],
#        [47],
#        [47],
#        [40],
#        [51],
#        [49],
#        [42],
#        [54],
#        [58],
#        [62],
#        [54],
#        [61],
#        [62],
#        [56],
#        [54],
#        [61],
#        [57],
#        [55],
# ...

# %%
y
# Out:
# array([[154.25],
#        [173.25],
#        [154.  ],
#        [184.75],
#        [184.25],
#        [210.25],
#        [181.  ],
#        [176.  ],
#        [191.  ],
#        [198.25],
#        [186.25],
#        [216.  ],
#        [180.5 ],
#        [205.25],
#        [187.75],
#        [162.75],
#        [195.75],
#        [209.25],
#        [183.75],
#        [211.75],
#        [179.  ],
#        [200.5 ],
#        [140.25],
#        [148.75],
#        [151.25],
#        [159.25],
#        [131.5 ],
#        [148.  ],
#        [133.25],
#        [160.75],
#        [182.  ],
#        [160.25],
#        [168.  ],
#        [218.5 ],
#        [247.25],
#        [191.75],
#        [202.25],
#        [196.75],
#        [363.15],
#        [203.  ],
#        [262.75],
#        [205.  ],
#        [217.  ],
#        [212.  ],
#        [125.25],
#        [164.25],
#        [133.5 ],
#        [148.5 ],
#        [135.75],
#        [127.5 ],
#        [158.25],
#        [139.25],
# ...

# %%
plt.plot(x,color='blue')
plt.plot(y,color='yellow')
plt.show()

# %%
plt.plot(x,color='blue')
plt.plot(y,color='yellow')
plt.xlabel('Age',)
plt.ylabel('Weight')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,
                                              test_size=0.2,
                                              random_state=0)

# %%
x_train.shape
# Out:
# (201, 1)

# %%
x_test.shape
# Out:
# (51, 1)

# %%
y_train.shape
# Out:
# (201, 1)

# %%
y_test.shape
# Out:
# (51, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(x_test)

# %%
y_predict
# Out:
# array([[181.40855916],
#        [176.6796506 ],
#        [180.81744559],
#        [179.28055031],
#        [181.88145002],
#        [179.87166388],
#        [180.22633202],
#        [178.45299131],
#        [177.74365503],
#        [179.75344116],
#        [181.88145002],
#        [178.09832317],
#        [180.22633202],
#        [180.10810931],
#        [181.7632273 ],
#        [178.45299131],
#        [179.75344116],
#        [180.81744559],
#        [181.64500459],
#        [179.04410488],
#        [180.10810931],
#        [179.87166388],
#        [177.27076417],
#        [180.22633202],
#        [179.87166388],
#        [176.20675974],
#        [181.99967273],
#        [178.57121402],
#        [179.98988659],
#        [179.04410488],
#        [176.79787331],
#        [179.98988659],
#        [179.87166388],
#        [180.22633202],
#        [180.81744559],
#        [182.11789545],
#        [180.10810931],
#        [182.11789545],
#        [181.29033645],
#        [180.10810931],
# ...

# %%
mass=pd.DataFrame(y_test,columns=['Weight'])

# %%
mass
# Out:
#     Weight
# 0   136.50
# 1   170.75
# 2   152.25
# 3   173.75
# 4   152.25
# 5   170.75
# 6   191.00
# 7   198.50
# 8   178.00
# 9   186.00
# 10  223.00
# 11  175.50
# 12  168.50
# 13  202.25
# 14  156.75
# 15  125.00
# 16  208.75
# 17  125.75
# 18  182.50
# 19  162.50
# 20  210.50
# 21  164.25
# 22  189.75
# 23  168.25
# 24  170.75
# 25  207.50
# 26  191.00
# 27  198.00
# 28  156.25
# 29  196.75
# 30  215.50
# 31  177.50
# 32  183.25
# 33  145.75
# 34  228.25
# 35  156.00
# 36  232.75
# 37  210.25
# 38  140.25
# 39  153.00
# 40  167.00
# 41  180.50
# 42  223.00
# 43  187.25
# 44  177.00
# 45  165.25
# 46  155.25
# 47  125.25
# 48  205.50
# 49  118.50
# 50  146.75

# %%
mass['predicted']=y_predict

# %%
mass
# Out:
#     Weight   predicted
# 0   136.50  181.408559
# 1   170.75  176.679651
# 2   152.25  180.817446
# 3   173.75  179.280550
# 4   152.25  181.881450
# 5   170.75  179.871664
# 6   191.00  180.226332
# 7   198.50  178.452991
# 8   178.00  177.743655
# 9   186.00  179.753441
# 10  223.00  181.881450
# 11  175.50  178.098323
# 12  168.50  180.226332
# 13  202.25  180.108109
# 14  156.75  181.763227
# 15  125.00  178.452991
# 16  208.75  179.753441
# 17  125.75  180.817446
# 18  182.50  181.645005
# 19  162.50  179.044105
# 20  210.50  180.108109
# 21  164.25  179.871664
# 22  189.75  177.270764
# 23  168.25  180.226332
# 24  170.75  179.871664
# 25  207.50  176.206760
# 26  191.00  181.999673
# 27  198.00  178.571214
# 28  156.25  179.989887
# 29  196.75  179.044105
# 30  215.50  176.797873
# 31  177.50  179.989887
# 32  183.25  179.871664
# 33  145.75  180.226332
# 34  228.25  180.817446
# 35  156.00  182.117895
# 36  232.75  180.108109
# 37  210.25  182.117895
# 38  140.25  181.290336
# ...

# %%
plt.scatter(x,y,color='red')
plt.show()

# %%
plt.scatter(x,y,color='red')
plt.plot(x_test,y_predict,color='blue')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 808.5809244322393

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 23.122194221128513

# %%
r2_score(y_test,y_predict)
# Out:
# -0.03329135316513443
